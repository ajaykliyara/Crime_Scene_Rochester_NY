# %%
#importing required packages
import pandas as pd
import numpy as np
import time

# %%
#reading data from csv
crime_raw_data = pd.read_csv('data/rpd_crime_2011_to_present.csv')

# %%
print("Shape of imported data file {}".format(crime_raw_data.shape))
# Out:
# Shape of imported data file (76228, 40)

# %%
#sample data
crime_raw_data.head(2)
# Out:
#            X          Y  OBJECTID                         Geocode_Address  \
# 0 -77.643682  43.154498      2001       166 Syke St, Rochester, NY, 14611
# 1 -77.643582  43.177149      2002  506 Glenwood Ave, Rochester, NY, 14613
#
#      Geocode_Street    Case_Number  OccurredFrom_Date_Year  \
# 0       166 SYKE ST  2011-00060353                    2011
# 1  506 GLENWOOD AVE  2013-00070133                    2013
#
#    OccurredFrom_Date_Month  OccurredFrom_Time    OccurredFrom_Timestamp  \
# 0                        2               1200  2011-02-21T12:00:00.000Z
# 1                        3               2130  2013-03-16T21:30:00.000Z
#
#         ...        Statute_Text  \
# 0       ...            Burglary
# 1       ...             Larceny
#
#                                  Statute_Description  Statute_CrimeCategory  \
# 0  Burglary 3rd: Illegal Entry with Intent to Com...                      5
# 1  Petit Larceny                                 ...                      6
#
#   Statute_Attempted       Weapon_Description              Larceny_Type  \
# 0         Completed  * No Weapon Specified *       Theft from Building
# 1         Completed  * No Weapon Specified *  Theft from Motor Vehicle
#
#         Location_Type Geo_Beat Geo_Section Geo_Section_Num
# 0  Single Family Home    203.0     Genesee             3.0
# 1              Street    241.0        Lake             1.0
#
# [2 rows x 40 columns]

# %%
#all attributes in the data
crime_raw_data.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'Geocode_Address', 'Geocode_Street',
#        'Case_Number', 'OccurredFrom_Date_Year', 'OccurredFrom_Date_Month',
#        'OccurredFrom_Time', 'OccurredFrom_Timestamp',
#        'OccurredThrough_Date_Year', 'OccurredThrough_Date_Month',
#        'OccurredThrough_Time', 'OccurredThrough_Timestamp',
#        'Reported_Date_Year', 'Reported_Date_Month', 'Reported_Time',
#        'Reported_Timestamp', 'Address_StreetFull', 'Address_City',
#        'Address_State', 'Patrol_Beat', 'Patrol_Section', 'Case_Status',
#        'Statute_Title', 'Statute_Section', 'Statute_Subsection',
#        'Statute_Degree', 'Statute_Class', 'Statute_Category', 'Statute_Text',
#        'Statute_Description', 'Statute_CrimeCategory', 'Statute_Attempted',
#        'Weapon_Description', 'Larceny_Type', 'Location_Type', 'Geo_Beat',
#        'Geo_Section', 'Geo_Section_Num'],
#       dtype='object')

# %%
#installing folium to enable easy viewing of data on a map
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.5.0.tar.gz (79kB)
#     100% |████████████████████████████████| 81kB 1.2MB/s ta 0:00:01
# Collecting branca (from folium)
#   Downloading branca-0.2.0-py3-none-any.whl
# Requirement already satisfied: jinja2 in /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages (from folium)
# Requirement already satisfied: requests in /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages (from folium)
# Requirement already satisfied: six in /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages (from folium)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages (from jinja2->folium)
# Building wheels for collected packages: folium
# done
#   Stored in directory: /Users/ajaykliyara/Library/Caches/pip/wheels/04/d0/a0/b2b8356443364ae79743fce0b9b6a5b045f7560742129fde22
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.2.0 folium-0.5.0

# %%
#importing folium
#reference : https://blog.dominodatalab.com/creating-interactive-crime-maps-with-folium/
import folium

# %%
crime_type_list = list(crime_raw_data.Statute_Text.unique())
crime_type_list
# Out:
# ['Burglary',
#  'Larceny',
#  'Aggravated Assault',
#  'Motor Vehicle Theft',
#  'Robbery',
#  'Murder',
#  'Non-Negligent Manslaughter']

# %%
import seaborn as sns
col_palette = sns.color_palette("hls", 8)
col_palette_hex = col_palette.as_hex()
col_palette_hex
# Out:
# ['#db5f57',
#  '#dbc257',
#  '#91db57',
#  '#57db80',
#  '#57d3db',
#  '#5770db',
#  '#a157db',
#  '#db57b2']

# %%
ROC_COORDINATES = (43.16, -77.61)

# for speed purposes
MAX_RECORDS = 1000
 
# create empty map zoomed in on Rochester, NY
map = folium.Map(location=ROC_COORDINATES, tiles='Stamen Toner', zoom_start=8)

#start time 
start_time = time.time()

# add a marker for every record in the filtered data, use a clustered view
for each in crime_raw_data[0:MAX_RECORDS].iterrows():
    if(not np.isnan(each[1]['X'])):
        location = [each[1]['Y'],each[1]['X']]
        tooltip = 'city : ' + each[1]['Address_City'] + '\n crime type : ' + each[1]['Statute_Text']
        index = crime_type_list.index(each[1]['Statute_Text'])
        col = col_palette_hex[index]
        folium.CircleMarker(location,
                        radius=2,
                        popup=tooltip,
                        color=col,
                        fill_color=col,
                       ).add_to(map)


print("---Execution Time {} minutes ---".format((time.time() - start_time)/60))
map
# Out:
# ---Execution Time 0.5449555357297261 minutes ---
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#legend
import branca.colormap as cm
step = cm.StepColormap(
    col_palette_hex,
    vmin=0, vmax=14,
    index=[0, 2, 4, 6, 8, 10, 12]
)

print(crime_type_list)
step
# Out:
# ['Burglary', 'Larceny', 'Aggravated Assault', 'Motor Vehicle Theft', 'Robbery', 'Murder', 'Non-Negligent Manslaughter']
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#db5f57;stroke-width:3;" /><line x1="51" ...

# %%
# Out:
# ['Burglary', 'Larceny', 'Aggravated Assault', 'Motor Vehicle Theft', 'Robbery', 'Murder', 'Non-Negligent Manslaughter']

# %%
for val in crime_type_list:
    index = crime_type_list.index(val)
    col = fg(col_palette_hex[index])
    print(colored(val,col))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-432d55e6378d> in <module>()
#       1 for val in crime_type_list:
#       2     index = crime_type_list.index(val)
# ----> 3     col = fg(col_palette_hex[index])
#       4     print(colored(val,col))
#       5
#
# /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages/colored/colored.py in fg(color)
#     379 def fg(color):
#     380     """alias for colored().foreground()"""
# --> 381     return colored(color).foreground()
#     382
#     383
#
# /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages/colored/colored.py in __init__(self, color)
#      47
#      48         if str(color).startswith("#"):
# ---> 49             self.HEX = HEX(color.lower())
#      50         else:
#      51             self.HEX = ""
#
# /Users/ajaykliyara/anaconda_py3/anaconda/lib/python3.5/site-packages/colored/hex.py in HEX(color)
#     289     # swap keys for values
#     290     new_xterm_colors = dict(zip(xterm_colors.values(), xterm_colors.keys()))
# --> 291     return new_xterm_colors[color]
#
# KeyError: '#db5f57'

# %%
for each in crime_raw_data[0:MAX_RECORDS].iterrows():
    print(each[1])
    break
# Out:
# X                                                                      -77.6437
# Y                                                                       43.1545
# OBJECTID                                                                   2001
# Geocode_Address                               166 Syke St, Rochester, NY, 14611
# Geocode_Street                                                      166 SYKE ST
# Case_Number                                                       2011-00060353
# OccurredFrom_Date_Year                                                     2011
# OccurredFrom_Date_Month                                                       2
# OccurredFrom_Time                                                          1200
# OccurredFrom_Timestamp                                 2011-02-21T12:00:00.000Z
# OccurredThrough_Date_Year                                                  2011
# OccurredThrough_Date_Month                                                    3
# OccurredThrough_Time                                                       1220
# OccurredThrough_Timestamp                              2011-03-01T12:20:00.000Z
# Reported_Date_Year                                                         2011
# Reported_Date_Month                                                           3
# Reported_Time                                                              1300
# Reported_Timestamp                                     2011-03-01T18:00:00.000Z
# Address_StreetFull                                                  166 SYKE ST
# Address_City                                                          Rochester
# Address_State                                                                NY
# Patrol_Beat                                                                 203
# Patrol_Section                                                          Genesee
# Case_Status                                                              Office
# Statute_Title                                                               PL
# Statute_Section                                                           140.2
# Statute_Subsection
# Statute_Degree                                                                3
# Statute_Class                                                                 D
# Statute_Category                                                              F
# Statute_Text                                                           Burglary
# Statute_Description           Burglary 3rd: Illegal Entry with Intent to Com...
# Statute_CrimeCategory                                                         5
# Statute_Attempted                                                     Completed
# Weapon_Description                                      * No Weapon Specified *
# Larceny_Type                                                Theft from Building
# Location_Type                                                Single Family Home
# Geo_Beat                                                                    203
# Geo_Section                                                             Genesee
# Geo_Section_Num                                                               3
# Name: 0, dtype: object
